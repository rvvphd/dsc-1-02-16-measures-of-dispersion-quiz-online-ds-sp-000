# %% [markdown]
# # Measures of Dispersion - Quiz
#
# ## Objectives
# You will be able to:
# * Describe the significance of calculating measures of dispersion for continuous data
# * Understand the formula and intuition behind mean absolute deviation, standard deviation and variance
# * Understand the formula and intuition behind quantiles/quartiles and percentiles
# * Understand and interpret Interquartile distances with box plots

# %% [markdown]
# ## Exercise 1
# Summary statistics for two samples of data are
# ```
# Sample 1:
# mean = 19
# variance = 10
#
# Sample 2:
# mean = 10
# variance = 19
# ```
# Which sample has the larger spread of observations?

# %%
# The variance is larger for sample 2.

# %% [markdown]
# ## Exercise 2
# Consider the following ordered set of data
# ```
# 4 4 4 9 5 0 5 1 5 3 5 7 5 8 6 2
#
# 6 6 6 6 6 8 7 1 7 5 7 7 8 0 8 5
# ```
#
# * What is the IQR?
# * Optional extension: Verify your answer in Python

# %%
# 3
import numpy as np
a = np.array([4, 4, 4, 9, 5, 0, 5, 1, 5, 3, 5, 7, 5, 8, 6, 2, 6, 6, 6, 6, 6, 8, 7, 1, 7, 5, 7, 7, 8, 0, 8, 5])
np.percentile(a, 75, interpolation='higher') - np.percentile(a, 25, interpolation='lower')
# Out:
# 3

# %% [markdown]
# ### Exercise 3
# Create a box-and-whisker plot for the judges' scores for an artist's performances in a talent competition.
#
# ```
# Evan L	52
# Nicole S  50
# Pamela A  47
# Chad O	44
# Erin A	39
# Jake P	38
# Niecy N   36
# Kate G	32
# ```
# Create a box plot in matplotlib to identify the median for giving a final score to the artist. Are there any outliers ?

# %%
# Your answer here 
import matplotlib.pyplot as plt
plt.style.use('ggplot') # for viewing a grid on plot
x = [32, 36, 38, 39, 44, 47, 50, 52] 
plt.boxplot(x,  showfliers=False)
plt.title ("Scores without Outliers")
plt.show()

# %%
# # Your answer here 
# No outliers
plt.boxplot(x)
plt.title ("Scores - with outliers")
plt.show()

# %% [markdown]
# ### Exercise 4
# Imagine that the number of marriages registered over a 10 year period were as follows:
#
# Table 1.  Number of registered marriages
# ```
# Year  Number of marriages
#
# 1	40,650
# 2	40,812
# 3	41,300
# 4	41,450
# 5	39,594
# 6	40,734
# 7	39,993
# 8	38,814
# 9	37,828
# 10   35,716
# ```
# Using the data above:
#
# ####  Find the median

# %%
# 40,300
import matplotlib.pyplot as plt
plt.style.use('ggplot') # for viewing a grid on plot
x = [35716, 37828, 38814, 39594, 39993, 40650, 40734, 40812, 41300, 41450] 
plt.boxplot(x,  showfliers=False)
plt.title ("Number of Marriages without Outliers")
plt.show()

# %% [markdown]
# #### Find the upper and lower quartiles

# %%
# Q1 = 38.814 Q3 = 40.812 # Your answer here 
import numpy as np
a = np.array([35716, 37828, 38814, 39594, 39993, 40650, 40734, 40812, 41300, 41450])
np.percentile(a, 75, interpolation='higher')
np.percentile(a, 25, interpolation='lower')
# Out:
# 38814

# %% [markdown]
# #### Calculate the interquartile range

# %%
# Your answer here 
a = np.array([35716, 37828, 38814, 39594, 39993, 40650, 40734, 40812, 41300, 41450])
np.percentile(a, 75, interpolation='higher') - np.percentile(a, 25, interpolation='lower')
# Out:
# 1998

# %% [markdown]
# #### Plot a boxplot to verify your answers

# %%
# Your answer here 
import matplotlib.pyplot as plt
plt.style.use('ggplot') # for viewing a grid on plot
x = [35716, 37828, 38814, 39594, 39993, 40650, 40734, 40812, 41300, 41450] 
plt.boxplot(x,  showfliers=False)
plt.title ("Number of Marriages without Outliers")
plt.show()
